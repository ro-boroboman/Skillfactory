# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
pd.options.display.max_rows = 999

# %%
data = pd.read_csv('D:/movie_bd_v5.xls')
data.head(10)
# Out:
#      imdb_id     budget     revenue                original_title  \
# 0  tt0369610  150000000  1513528810                Jurassic World
# 1  tt1392190  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446  110000000   295238201                     Insurgent
# 3  tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852  190000000  1506249360                     Furious 7
# 5  tt1663202  135000000   532950503                  The Revenant
# 6  tt1340138  155000000   440603537            Terminator Genisys
# 7  tt3659388  108000000   595380321                   The Martian
# 8  tt2293640   74000000  1156730962                       Minions
# 9  tt2096673  175000000   853708609                    Inside Out
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# ...

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

df= data # создаем копию датафрейма чтобы при порче фрэйма не иницилизировать его заново


# тут другие ваши предобработки колонок например:
df.loc[:, 'profit'] = df["revenue"]- df['budget'] # добаляем колонку профит 
#the time given in the dataset is in string format.
#So we need to change this in datetime format
answers
# Out:
# {}

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
# Пример: 
answers['1'] = '2. Spider-Man 3 (tt0413300)'
# запишите свой вариант ответа
answers['1'] = '1. Pirates of the Caribbean: On Stranger Tides (tt1298650)'
# если ответили верно, можете добавить комментарий со значком "+"

# %%
# тут пишем ваш код для решения данного вопроса:
display(df[(df.budget==df.budget.max())])
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year     profit
# 723           6.3          2011  641683000

# %% [markdown]
# ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
# думаю логику работы с этим словарем вы уже поняли, 
# по этому не буду больше его дублировать

answers['2'] = '2. Gods and Generals (tt0279111) '

# %%
display(df[(df.runtime==df.runtime.max())])
#df[(df.imdb_id=="tt0167260")] # проверка длительности властелина колец , забавный факт в гугле его длительность больше чем значение в датафрейме и по идее он самый длинный :)
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1157  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_average  release_year    profit
# 1157           5.8          2003 -43076064

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)

# %%
display(df[(df.runtime==df.runtime.min())])
answers["3"] = "3. Winnie the Pooh (tt1449283)"
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year    profit
# 768    4/13/2011           6.8          2011 -15540000

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
display(df["runtime"].mean())
# Так же можно узнать через .describe
answers["4"] = "4. 110"
# Out:
# 109.6585494970884

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
display(df["runtime"].median())
# Так же можно узнать через .describe
answers["5"]= "5. 107"
# Out:
# 107.0

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
display(df[(df.profit==df.profit.max())])
answers["6"]= "6. Avatar (tt0499549)"
# Out:
#        imdb_id     budget     revenue original_title  \
# 239  tt0499549  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_average  release_year      profit
# 239           7.1          2009  2544505847

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
display(df[(df.profit==df.profit.min())])
answers["7"]= "7. The Lone Ranger (tt1210819)"
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
display(df[(df.revenue>df.budget)].count())
answers["8"]= "8. 1478"
# Out:
# imdb_id                 1478
# budget                  1478
# revenue                 1478
# original_title          1478
# cast                    1478
# director                1478
# tagline                 1478
# overview                1478
# runtime                 1478
# genres                  1478
# production_companies    1478
# release_date            1478
# vote_average            1478
# release_year            1478
# profit                  1478
# dtype: int64

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
#df[( df.release_year == 2008)& (df.revenue == df.revenue.max()) ] Этот код почему-то не работает 
rev=df[( df.release_year == 2008)]
display(rev[rev.revenue== rev.revenue.max()])
answers["9"]= "9. The Dark Knight (tt0468569)"
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 599      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_average  release_year     profit
# 599           8.1          2008  816921825

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
display(df[(df.release_year>=2012) & (df.release_year<=2014) & (df.profit== df.profit.min()) ])
answers["10"]= "10. The Lone Ranger (tt1210819)"
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
genres=pd.Series(df['genres'].str.cat(sep='|').split('|')).value_counts(ascending=False)
genres
answers["11"]= "11. Drama"






# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
profit=df[df.profit>0]
genres2=pd.Series(profit['genres'].str.cat(sep='|').split('|')).value_counts(ascending=False)
#display(profit)
display(genres2)
answers["12"]= "12. Drama"
# Out:
# Drama              560
# Comedy             551
# Thriller           446
# Action             444
# Adventure          337
# Romance            242
# Crime              231
# Family             226
# Science Fiction    195
# Fantasy            188
# Horror             150
# Animation          120
# Mystery            119
# Music               47
# History             46
# War                 41
# Western             12
# Documentary          7
# dtype: int64

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сбооры?

# %%
sbor=df.groupby(['director'])["revenue"].sum().sort_values(ascending=False)
display(sbor)
answers["13"]= "13. Peter Jackson"
# Out:
# director
# Peter Jackson                                                                                                                                                                6490593685
# Christopher Nolan                                                                                                                                                            4167548502
# David Yates                                                                                                                                                                  4154295625
# Michael Bay                                                                                                                                                                  3886938960
# J.J. Abrams                                                                                                                                                                  3579169916
# ...

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
# Out:
#   File "<ipython-input-23-81f13ba6c5e3>", line 4
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
answers["14"]= "14. Robert Rodriguez"
movies = df[df['genres'].str.match('Action')]
movies.groupby(['director'])["original_title"].count().sort_values(ascending=False)
# Out:
# director
# Robert Rodriguez                                   5
# Tony Scott                                         5
# Antoine Fuqua                                      5
# Andrzej Bartkowiak                                 5
# Zack Snyder                                        4
# Justin Lin                                         4
# Renny Harlin                                       4
# Paul W.S. Anderson                                 4
# Paul Greengrass                                    4
# Brett Ratner                                       4
# Ridley Scott                                       4
# Rob Cohen                                          4
# John Moore                                         4
# Doug Liman                                         3
# Simon West                                         3
# Christopher Nolan                                  3
# Pierre Morel                                       3
# ...

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
df2012 = df[df.release_year == 2012]
df2012['cast_new'] = df2012['cast'].str.split('|')
df2012=df2012.explode('cast_new')
answers["15"]="15. Chris Hemsworth"
df2012.groupby(['cast_new'])["revenue"].sum().sort_values(ascending=False)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# cast_new
# Chris Hemsworth            2027450773
# Denis Leary                1629460639
# Anne Hathaway              1522851057
# Chris Evans                1519557910
# Robert Downey Jr.          1519557910
# Mark Ruffalo               1519557910
# Scarlett Johansson         1519557910
# Ralph Fiennes              1409561013
# Sacha Baron Cohen          1368110577
# Kristen Stewart            1234384318
# Emma Thompson              1163009983
# Tom Hardy                  1134717867
# Seann William Scott        1112234366
# Judi Dench                 1108561013
# Daniel Craig               1108561013
# ...

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
df1=df
df1['cast_new'] = df1['cast'].str.split('|')
df1=df1.explode('cast_new')
answers["16"]="16. Matt Damon "
df1[(df['budget'] > df['budget'].mean())].cast_new.value_counts()
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# Matt Damon             18
# Adam Sandler           17
# Angelina Jolie         16
# Tom Cruise             15
# Eddie Murphy           15
#                        ..
# Tilda Swinton           1
# Thomas Haden Church     1
# Burn Gorman             1
# Luke Ford               1
# Ryan Gosling            1
# Name: cast_new, Length: 1505, dtype: int64

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
df1["genres_new"]= df1["genres"].str.split('|')
df1=df1.explode('genres_new')
answers["17"]= "17. Action "
display(df1[df1["cast_new"] == "Nicolas Cage" ].genres_new.value_counts())
# Out:
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Mystery             3
# Family              3
# Animation           3
# History             2
# Horror              1
# War                 1
# Romance             1
# Name: genres_new, dtype: int64

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
df["production"]= df["production_companies"].str.split('|')
df=df.explode('production')
df2=df[df["production"] == "Paramount Pictures" ]
answers["18"]= "18. K-19: The Widowmaker "
grouped_df = df2.groupby(['original_title'])['profit'].min().sort_values(ascending=True)
grouped_df
# Out:
# original_title
# K-19: The Widowmaker                                  -64831034
# Timeline                                              -60519261
# Next                                                  -51788987
# Alfie                                                 -46604061
# Twisted                                               -24805000
# Domestic Disturbance                                  -20750706
# The Love Guru                                         -20180936
# A Thousand Words                                      -17955723
# The Fighter                                           -15809131
# Abandon                                               -14280643
# Suspect Zero                                          -14000000
# Serving Sara                                          -12069815
# Sky Captain and the World of Tomorrow                 -12041304
# Sahara                                                -10730514
# ...

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
answers["19"]= "19. 2015 "
data.groupby(['release_year'])['revenue'].sum().sort_values(ascending=False)
# Out:
# release_year
# 2015    25449202382
# 2014    23405862953
# 2013    23213799791
# 2012    23079001687
# 2011    22676791872
# 2010    21071204961
# 2009    20261791024
# 2008    18252781990
# 2007    18162406801
# 2004    15663430720
# 2005    15309425558
# 2006    14775042320
# 2003    14346123312
# 2002    14136361487
# 2001    13017764865
# 2000    10664099805
# Name: revenue, dtype: int64

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
df2=df[df["production"] == "Warner Bros." ]
grouped_df = df2.groupby(['release_year'])['profit'].sum().sort_values(ascending=True)
answers["20"]= "20. 2007 "
grouped_df
# Out:
# release_year
# 2000     471305068
# 2006     614989614
# 2015     870368348
# 2002    1072248589
# 2012    1258020056
# 2001    1428174853
# 2005    1551980298
# 2013    1636453400
# 2004    1675125175
# 2009    1833481628
# 2010    1853128844
# 2003    1855493377
# 2011    1871393682
# 2014    1886303827
# 2008    2134595031
# 2007    2167367993
# Name: profit, dtype: int64

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
# Out:
#         imdb_id     budget     revenue  original_title  \
# 0     tt0369610  150000000  1513528810  Jurassic World
# 0     tt0369610  150000000  1513528810  Jurassic World
# 0     tt0369610  150000000  1513528810  Jurassic World
# 0     tt0369610  150000000  1513528810  Jurassic World
# 0     tt0369610  150000000  1513528810  Jurassic World
# ...         ...        ...         ...             ...
# 1887  tt0162983   40000000    36037909      Hanging Up
# 1887  tt0162983   40000000    36037909      Hanging Up
# 1887  tt0162983   40000000    36037909      Hanging Up
# 1887  tt0162983   40000000    36037909      Hanging Up
# 1888  tt0163676   15000000     5217498    The In Crowd
#
#                                                    cast         director  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# ...

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '1. Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '2': '2. Gods and Generals (tt0279111) ',
#  '3': '3. Winnie the Pooh (tt1449283)',
#  '4': '4. 110',
#  '5': '5. 107',
#  '6': '6. Avatar (tt0499549)',
#  '7': '7. The Lone Ranger (tt1210819)',
#  '8': '8. 1478',
#  '9': '9. The Dark Knight (tt0468569)',
#  '10': '10. The Lone Ranger (tt1210819)',
#  '11': '11. Drama',
#  '12': '12. Drama',
#  '13': '13. Peter Jackson',
#  '14': '14. Robert Rodriguez',
#  '15': '15. Chris Hemsworth',
#  '16': '16. Matt Damon ',
#  '17': '17. Action ',
#  '18': '18. K-19: The Widowmaker ',
#  '19': '19. 2015 ',
#  '20': '20. 2007 '}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 14
